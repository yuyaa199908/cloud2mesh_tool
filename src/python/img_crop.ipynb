# %%
from PIL import Image

# %%
img_name = "1"
im = Image.open('../img/3/{}.png'.format(img_name))
im_crop = im.crop((560, 350,2360,1130))
im_crop
# Out:
# <PIL.Image.Image image mode=RGBA size=1800x780>

# %%
for i in range(1,17):
    im = Image.open('../img/3/{}.png'.format(i))
    im_crop =  im.crop((560, 350,2360,1130)).save('../img/3_croped/{}_croped.png'.format(i))
